# %%
# 
# MC Data Bootcamp 2019
# Project #1
# Name: Sungyong In
#

import pandas as pd
import numpy as n

# 
# Load DC property data, DC_properties.csv, into a dataframe
#

df = pd.read_csv("datasets/DC_properties.csv")
df.shape
df.head()
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# ...

# %%
# let's find about the size of the dataset
df.shape
# Out:
# (158957, 49)

# %%
# Let's drop duplicate rows
#df_clean = df.drop_duplicates()

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
# Let's print out column headings/indexes
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
# Let's drop the column heading called 'Unnamed: 0' from the dataframe, df, and save it into another dataframe, df2.
df2 = df.drop('Unnamed: 0', axis=1)
df2.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS', 'BEDRM',
#        'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE', 'QUALIFIED',
#        'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE', 'CNDTN',
#        'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES', 'USECODE',
#        'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM', 'LIVING_GBA',
#        'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE',
#        'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT',
#        'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df2.head()
# Out:
#    BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 0       4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1       3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2       3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3       3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4       2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#    YR_RMDL   EYB  ...  LONGITUDE ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0   1988.0  1972  ... -77.040832      Old City 2    040 D Old City 2
# 1   2007.0  1972  ... -77.040764      Old City 2    040 D Old City 2
# 2   2009.0  1984  ... -77.040678      Old City 2    040 D Old City 2
# 3   2003.0  1984  ... -77.040629      Old City 2    040 D Old City 2
# 4   2012.0  1985  ... -77.039361      Old City 2    040 D Old City 2
#
#   CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
# Let's find out duplicate rows from the dataframe, df2, and save it as "dupe".
dupe = df2.duplicated()
df2[dupe]
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 75079        4          0  Hot Water Rad  N        4.0     16      4  1932.0
# 106715       1          0        Ht Pump  Y        NaN      4      2  1937.0
# 106716       1          0        Ht Pump  Y        NaN      4      2  1937.0
# 106717       1          0        Ht Pump  Y        NaN      4      2  1937.0
# 106784       1          0      Warm Cool  Y        NaN      3      1  1967.0
# 106968       1          0        Ht Pump  Y        NaN      3      1  1952.0
# 106969       1          0        Ht Pump  Y        NaN      3      1  1952.0
# 106970       1          0        Ht Pump  Y        NaN      3      1  1952.0
# 106973       1          0        Ht Pump  Y        NaN      3      1  1952.0
# 106974       1          0        Ht Pump  Y        NaN      3      1  1952.0
# 106975       1          0        Ht Pump  Y        NaN      3      1  1952.0
# ...

# %%
# Now, let's drop the duplicate rows from the new dataframe, df2, and save it into another dataframe, nodupe_df2.
nodupe_df2 = df2.drop_duplicates()
nodupe_df2.count()
# Out:
# BATHRM                157449
# HF_BATHRM             157449
# HEAT                  157449
# AC                    157449
# NUM_UNITS             106695
# ROOMS                 157449
# BEDRM                 157449
# AYB                   157180
# YR_RMDL                80001
# EYB                   157449
# STORIES               106651
# SALEDATE              131624
# PRICE                  97839
# QUALIFIED             157449
# SALE_NUM              157449
# GBA                   106695
# BLDG_NUM              157449
# STYLE                 106695
# STRUCT                106695
# GRADE                 106695
# CNDTN                 106695
# EXTWALL               106695
# ROOF                  106695
# INTWALL               106695
# KITCHENS              106694
# FIREPLACES            157449
# USECODE               157449
# LANDAREA              157449
# GIS_LAST_MOD_DTTM     157449
# SOURCE                157449
# CMPLX_NUM              50754
# LIVING_GBA             50754
# ...

# %%
# Let's check the size of the new dataframe 'nodupe_df2'
nodupe_df2.shape
# Out:
# (157449, 48)

# %%
nodupe_df2.head()
# Out:
#    BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 0       4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1       3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2       3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3       3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4       2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#    YR_RMDL   EYB  ...  LONGITUDE ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# 0   1988.0  1972  ... -77.040832      Old City 2    040 D Old City 2
# 1   2007.0  1972  ... -77.040764      Old City 2    040 D Old City 2
# 2   2009.0  1984  ... -77.040678      Old City 2    040 D Old City 2
# 3   2003.0  1984  ... -77.040629      Old City 2    040 D Old City 2
# 4   2012.0  1985  ... -77.039361      Old City 2    040 D Old City 2
#
#   CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
# Let's find out about statistics on the new dataframe, nodupe_df2.
nodupe_df2.describe()
# Out:
#               BATHRM      HF_BATHRM      NUM_UNITS          ROOMS  \
# count  157449.000000  157449.000000  106695.000000  157449.000000
# mean        1.816601       0.461273       1.198013       6.213377
# std         0.978298       0.588547       0.596866       2.615108
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       1.000000       4.000000
# 50%         2.000000       0.000000       1.000000       6.000000
# 75%         2.000000       1.000000       1.000000       7.000000
# max        14.000000      11.000000       6.000000      48.000000
#
#                BEDRM            AYB       YR_RMDL            EYB  \
# count  157449.000000  157180.000000  80001.000000  157449.000000
# mean        2.746464    1941.807711   1998.316296    1963.745505
# std         1.355304      33.663140     16.588174      24.927464
# min         0.000000    1754.000000     20.000000    1800.000000
# ...

# %%
nodupe_df2['BATHRM'].max()
# Out:
# 14

# %%
# Shoe the number of non-NA values
nodupe_df2.count()
# Out:
# BATHRM                157449
# HF_BATHRM             157449
# HEAT                  157449
# AC                    157449
# NUM_UNITS             106695
# ROOMS                 157449
# BEDRM                 157449
# AYB                   157180
# YR_RMDL                80001
# EYB                   157449
# STORIES               106651
# SALEDATE              131624
# PRICE                  97839
# QUALIFIED             157449
# SALE_NUM              157449
# GBA                   106695
# BLDG_NUM              157449
# STYLE                 106695
# STRUCT                106695
# GRADE                 106695
# CNDTN                 106695
# EXTWALL               106695
# ROOF                  106695
# INTWALL               106695
# KITCHENS              106694
# FIREPLACES            157449
# USECODE               157449
# LANDAREA              157449
# GIS_LAST_MOD_DTTM     157449
# SOURCE                157449
# CMPLX_NUM              50754
# LIVING_GBA             50754
# ...

# %%
nodupe_df2.groupby('AC')

# %%
# Let's find out mean prices based on whether AC is present or not
copy_df3 = nodupe_df2['PRICE'].groupby(nodupe_df2['AC']).mean()

# %%
copy_df3.head()
# Out:
# AC
# 0    1.276661e+06
# N    3.467278e+05
# Y    8.074572e+05
# Name: PRICE, dtype: float64

# %%
copy_df3.shape
# Out:
# (3,)

# %%
copy_df3
# Out:
# AC
# 0    1.276661e+06
# N    3.467278e+05
# Y    8.074572e+05
# Name: PRICE, dtype: float64

# %%
# Let's find out mean prices based on bathrooms
nodupe_df2['PRICE'].groupby(nodupe_df2['BATHRM']).mean()
# Out:
# BATHRM
# 0     2.130826e+06
# 1     7.109289e+05
# 2     6.142221e+05
# 3     7.722337e+05
# 4     9.582736e+05
# 5     1.897948e+06
# 6     2.482814e+06
# 7     3.709859e+06
# 8     3.285536e+06
# 9     7.024559e+06
# 10    2.429286e+06
# 11    6.075000e+06
# 12    1.225000e+07
# 13             NaN
# 14             NaN
# Name: PRICE, dtype: float64

# %%
# Let's do a bit of clean-up of the dataset;
# Let's drop rows with no bathrooms and more than 5 bathrooms,and save it as 'new_df4'.
new_df4 = nodupe_df2.loc[(nodupe_df2['BATHRM'] >=1) & (nodupe_df2['BATHRM'] <=4)]

# %%
new_df4.shape
# Out:
# (155276, 48)

# %%
# Let's find out mean prices based on bathrooms again
new_df4['PRICE'].groupby(new_df4['BATHRM']).mean()
# Out:
# BATHRM
# 1    710928.857679
# 2    614222.082889
# 3    772233.701722
# 4    958273.614456
# Name: PRICE, dtype: float64

# %%
new_df4.tail()
# Out:
#         BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 158952       1          0  Forced Air  Y        NaN      3      1  1938.0
# 158953       1          0  Forced Air  Y        NaN      4      2  1938.0
# 158954       2          0  Forced Air  Y        NaN      4      2  1920.0
# 158955       1          0   Warm Cool  Y        NaN      2      0  1965.0
# 158956       1          0   Warm Cool  Y        NaN      2      0  1965.0
#
#         YR_RMDL   EYB  ...  LONGITUDE       ASSESSMENT_NBHD  \
# 158952   2006.0  1938  ...  -77.01942            Old City 2
# 158953   2006.0  1938  ...  -77.01942            Old City 2
# 158954   2007.0  1920  ...  -77.01942            Old City 2
# 158955      NaN  1965  ...  -77.01823  Southwest Waterfront
# 158956      NaN  1965  ...  -77.01823  Southwest Waterfront
#
#         ASSESSMENT_SUBNBHD CENSUS_TRACT  CENSUS_BLOCK    WARD  SQUARE  \
# 158952    040 B Old City 2       4801.0           NaN  Ward 6     477
# ...

# %%
# Let's drop a few columns, NUM_UNITS, CENSUS_BLOCK, WARD, 
new_df5 = new_df4.drop(['NUM_UNITS', 'CENSUS_BLOCK', 'WARD'], axis =1)

# %%
new_df5.tail()
# Out:
#         BATHRM  HF_BATHRM        HEAT AC  ROOMS  BEDRM     AYB  YR_RMDL   EYB  \
# 158952       1          0  Forced Air  Y      3      1  1938.0   2006.0  1938
# 158953       1          0  Forced Air  Y      4      2  1938.0   2006.0  1938
# 158954       2          0  Forced Air  Y      4      2  1920.0   2007.0  1920
# 158955       1          0   Warm Cool  Y      2      0  1965.0      NaN  1965
# 158956       1          0   Warm Cool  Y      2      0  1965.0      NaN  1965
#
#         STORIES  ... NATIONALGRID   LATITUDE LONGITUDE       ASSESSMENT_NBHD  \
# 158952      NaN  ...          NaN  38.911840 -77.01942            Old City 2
# 158953      NaN  ...          NaN  38.911840 -77.01942            Old City 2
# 158954      NaN  ...          NaN  38.911840 -77.01942            Old City 2
# 158955      NaN  ...          NaN  38.872953 -77.01823  Southwest Waterfront
# 158956      NaN  ...          NaN  38.872953 -77.01823  Southwest Waterfront
#
# ...

# %%
new_df5.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'ROOMS', 'BEDRM', 'AYB', 'YR_RMDL',
#        'EYB', 'STORIES', 'SALEDATE', 'PRICE', 'QUALIFIED', 'SALE_NUM', 'GBA',
#        'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE', 'CNDTN', 'EXTWALL', 'ROOF',
#        'INTWALL', 'KITCHENS', 'FIREPLACES', 'USECODE', 'LANDAREA',
#        'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM', 'LIVING_GBA', 'FULLADDRESS',
#        'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID', 'LATITUDE', 'LONGITUDE',
#        'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'SQUARE', 'X',
#        'Y', 'QUADRANT'],
#       dtype='object')

# %%
# Let's drop more columns, NUM_UNITS, CENSUS_BLOCK, WARD, 
new_df5 = new_df4.drop(['NUM_UNITS', 'CENSUS_BLOCK', 'WARD','NATIONALGRID', 'LATITUDE', 'LONGITUDE',
       'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD', 'CENSUS_TRACT', 'SQUARE', 'X',
       'Y', 'QUADRANT','USECODE','GBA','BLDG_NUM','CMPLX_NUM', 'LIVING_GBA'], axis =1)

# %%
new_df5.head()
# Out:
#    BATHRM  HF_BATHRM           HEAT AC  ROOMS  BEDRM     AYB  YR_RMDL   EYB  \
# 0       4          0      Warm Cool  Y      8      4  1910.0   1988.0  1972
# 1       3          1      Warm Cool  Y     11      5  1898.0   2007.0  1972
# 2       3          1  Hot Water Rad  Y      9      5  1910.0   2009.0  1984
# 3       3          1  Hot Water Rad  Y      8      5  1900.0   2003.0  1984
# 4       2          1      Warm Cool  Y     11      3  1913.0   2012.0  1985
#
#    STORIES  ...   INTWALL  KITCHENS FIREPLACES  LANDAREA    GIS_LAST_MOD_DTTM  \
# 0      3.0  ...  Hardwood       2.0          5      1680  2018-07-22 18:01:43
# 1      3.0  ...  Hardwood       2.0          4      1680  2018-07-22 18:01:43
# 2      3.0  ...  Hardwood       2.0          4      1680  2018-07-22 18:01:43
# 3      3.0  ...  Hardwood       2.0          3      1680  2018-07-22 18:01:43
# 4      3.0  ...  Hardwood       1.0          0      2032  2018-07-22 18:01:43
#
# ...
